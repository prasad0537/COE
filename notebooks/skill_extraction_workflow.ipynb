# %% [markdown]
# # Skill Extraction ML Workflow
#
# This notebook covers dataset generation, training, evaluation, and prediction.

# %%
from pathlib import Path
import json
import sys

PROJECT_ROOT = Path.cwd()
SRC_DIR = PROJECT_ROOT / "src"
if str(SRC_DIR) not in sys.path:
    sys.path.insert(0, str(SRC_DIR))

from common import DEFAULT_DATASET_CSV_PATH, DEFAULT_DATASET_PATH, DEFAULT_METRICS_PATH, DEFAULT_MODEL_PKL_PATH, DEFAULT_SAMPLE_TEXT_PATH
from prepare_dataset import build_dataset
from train_model import main as train_main

# %% [markdown]
# ## Generate Dataset

# %%
# !python src/prepare_dataset.py --samples-per-skill 24

# %% [markdown]
# ## Train Model

# %%
# !python src/train_model.py

# %% [markdown]
# ## View Metrics

# %%
metrics = json.loads(Path(DEFAULT_METRICS_PATH).read_text(encoding="utf-8"))
metrics

# %% [markdown]
# ## Predict on Sample Text

# %%
# !python src/predict_model.py --text-file data/raw/sample_job_description.txt

# %% [markdown]
# ## Files Produced

# %%
for path in [DEFAULT_DATASET_PATH, DEFAULT_DATASET_CSV_PATH, DEFAULT_MODEL_PKL_PATH, DEFAULT_METRICS_PATH]:
    print(path, "exists=" + str(Path(path).exists()))
